# %%
from qiskit import *
# Warning: you need to have utils.py in the notebook working directory
# You can se it with !pwd and change it with !cd (or using os module)
# %run utils.py

# %%
diffuser = build_diffuser(4)

# %%
diffuser.draw()
# Out:
#      ┌───┐┌───┐ ░                                     ░ ┌───┐┌───┐
# q_0: ┤ H ├┤ X ├─░───■─────────────────────────────■───░─┤ X ├┤ H ├
#      ├───┤├───┤ ░   │                             │   ░ ├───┤├───┤
# q_1: ┤ H ├┤ X ├─░───■─────────────────────────────■───░─┤ X ├┤ H ├
#      ├───┤├───┤ ░   │                             │   ░ ├───┤├───┤
# q_2: ┤ H ├┤ X ├─░───┼────■───────────────────■────┼───░─┤ X ├┤ H ├
#      ├───┤├───┤ ░   │    │                   │    │   ░ ├───┤├───┤
# q_3: ┤ H ├┤ X ├─░───┼────┼────■─────────■────┼────┼───░─┤ X ├┤ H ├
#      └───┘└───┘ ░ ┌─┴─┐  │    │         │    │  ┌─┴─┐ ░ └───┘└───┘
# q_4: ─────────────┤ X ├──■────┼─────────┼────■──┤ X ├─────────────
#                   └───┘┌─┴─┐  │         │  ┌─┴─┐└───┘
# q_5: ──────────────────┤ X ├──■─────────■──┤ X ├──────────────────
#                        └───┘┌─┴─┐     ┌─┴─┐└───┘
# q_6: ───────────────────────┤ X ├──■──┤ X ├───────────────────────
#                             └───┘┌─┴─┐└───┘
# q_7: ────────────────────────────┤ X ├────────────────────────────
#                                  └───┘

# %%
diffuser.measure_all()
count = simulate(diffuser)
plot_histogram(count)
